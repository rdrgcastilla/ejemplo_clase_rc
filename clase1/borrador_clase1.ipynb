# %% [markdown]
# <a href="https://colab.research.google.com/github/rdrgcastilla/ejemplo_clase_rc/blob/main/clase1/borrador_clase1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1 + 1
# Out:
# 2

# %% [markdown]
# # Este es el título
#
# ![lima-airports-partners-dharma-consulting.png](data:image/png;base64,...)

# %% [markdown]
# [texto del vínculo](https://www.google.com/url?sa=i&url=https%3A%2F%2Fcelluloidjunkie.com%2Fwire%2Freald-and-cinemark-renew-3d-agreement-through-2022%2F&psig=AOvVaw3yD6f_vbK5InsloG86fWCy&ust=1676773097501000&source=images&cd=vfe&ved=0CBAQjRxqFwoTCOjB_tmAnv0CFQAAAAAdAAAAABAJ)
